# %% [markdown]
# # biggest heading
# ## sub sub heading
# ### sub sub sub heading

# %% [markdown]
# ### emphasis
# print'hello world'

# %% [markdown]
# $ y = x + 2
# $ a^2 + b ^ 2 = c ^ 2 $

# %%
a, b,c = 10, -5, 0
a= -a 
b= -b 
c= -c 
print( a, b, c )
# Out:
# -10 5 0

# %%
print(' helloworld')
# Out:
#  helloworld

# %%
print(' Helloworld')
# Out:
#  Helloworld

# %%
5+10*(2/3)
# Out:
# 11.666666666666666

# %%
help(math.pow)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 help(math.pow)
#
# NameError: name 'math' is not defined

# %%
firstvariable = 'hello'

# %%
secondvariable = 'world '

# %%
print( firstvariable)
# Out:
# hello

# %%
print( secondvariable)
# Out:
# world

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(*args, sep=' ', end='\n', file=None, flush=False)
#     Prints the values to a stream, or to sys.stdout by default.
#
#     sep
#       string inserted between values, default a space.
#     end
#       string appended after the last value, default a newline.
#     file
#       a file-like object (stream); defaults to the current sys.stdout.
#     flush
#       whether to forcibly flush the stream.

# %%
help(import)
# Out:
#   Cell In[31], line 1
#     help(import)
#          ^
# SyntaxError: invalid syntax

# %%
x=-2.123
y=False
z='Deepak'
type(z)
# Out:
# str

# %%
x=2+5
print(x)
print('Hi guys the numberis', x)
# Out:
# 7
# Hi guys the numberis 7

# %%
my_float = 3.1415
print("value of my-float:", my_float)
print("type of my_float:", type(my_float))
# Out:
# value of my-float: 3.1415
# type of my_float: <class 'float'>

# %%
result = 10/2 
print(result)
type(result)
# Out:
# 5.0
# float

# %%
word = "ida cook dinner" 
print(word)
# Out:
# ida cook dinner

# %%
x = 0.1 + 0.5
print(x)
# Out:
# 0.6

# %%
x = 9.66e-2 
print("x is:",x)
# Out:
# x is: 0.0966

# %%
10//3
# Out:
# 3

# %%
result = "fuck you"
print(result)
# Out:
# fuck you

# %%
a=8
b=6
print("addition:",a+b)
# Out:
# addition: 14

# %%
3.14+12*11**4
# Out:
# 175695.14

# %%
x = 2
y = 3
print(x*y//2-x)
# Out:
# 1

# %%
15/4
# Out:
# 3.75

# %%
import math
help(math.pow)
print(x)
# Out:
# Help on built-in function pow in module math:
#
# pow(x, y, /)
#     Return x**y (x to the power of y).
# 8.0

# %%
print(math.floor(8,75))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 print(math.floor(8,75))
#
# TypeError: math.floor() takes exactly one argument (2 given)

# %%
print(random,random())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 print(random,random())
#
# NameError: name 'random' is not defined

# %%
import random
print(random.random())
print(random.uniform(-3.5,-3))
print(random.randint(-13,-10))
# Out:
# 0.03334788514286258
# -3.433739079870512
# -13

# %%
print("line1\nline2")
print("world1\
# Out:
# line1
# line2

# %%
x = "deepak"
print(x*3)
bb = input("enter ur name:")
print(bb)
# Out:
# deepakdeepakdeepak

# %%
s1 = "Hello world"
print(s1.isalpha())
